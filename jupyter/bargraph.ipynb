# %%
from matplotlib import pyplot as plt
x=[2017,2018,2019,2020]
y=[50,35,10,25]
c=["green","red","blue","pink"]
plt.barh(x,y,height=0.2,color=c)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()
