# %%
from matplotlib import pyplot as plt
rgukt=["cse","ece","mec","civil"]
students=[150,144,50,100]
c=["green","yellow","red","blue"]
plt.title("Rgukt pie chart")
plt.pie(students,colors=c,labels=rgukt,explode=[0.2,0,0,0])
plt.legend(rgukt)
plt.show()
