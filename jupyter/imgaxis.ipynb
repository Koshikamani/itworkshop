# %%
import matplotlib.pyplot as plt
img=plt.imread("/home/user/Pictures/Screenshots/dbms.png")
fig,ax=plt.subplots()
ax.imshow(img)
ax.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
