# %%
from matplotlib import pyplot as plt
x=[1,3,4,6,7,10]
y=[9,6,5,4,3,19]
z=[1,2,3,4,5,6,7,19,25]
v=[10,20,30,40,50,60]
plt.xlabel("a axis")
plt.ylabel("y axis")
plt.plot(z,linewidth=5.5,color="green")
plt.plot(v,linewidth=7.5,color="yellow")
plt.plot(x,y,linestyle="dashed",linewidth=2.5,color="red")
plt.show()
